# %%
import pandas as pd
import numpy as np

# %%
advTeamStats = pd.read_csv("Basketball_Stats/advanced_team_stats.csv")
finalSVUStats = pd.read_csv("Basketball_Stats/final_svu_teams.csv")
miscTeamStats = pd.read_csv("Basketball_Stats/misc_team_stats.csv")
winslosses = pd.read_csv("Basketball_Stats/nbaseas1.csv")
shotinfo = pd.read_csv("Basketball_Stats/nbaseas2.csv")
NBAstatsTeam = pd.read_csv("Basketball_Stats/nbaseasadv.csv")
teamDef = pd.read_csv("Basketball_Stats/nbaTeamDef2014_2016.csv")

# %%
advTeamStats.head()
# Out:
#    ast_pct  ast_ratio  ast_tov  def_rating  dreb_pct  efg_pct   game_id  \
# 0    0.650       19.6     1.37       110.6     0.667    0.581  21400008
# 1    0.743       21.2     2.00        94.6     0.756    0.558  21400032
# 2    0.684       19.0     1.86        98.2     0.711    0.457  21400064
# 3    0.615       17.3     1.41       100.0     0.744    0.523  21400071
# 4    0.545       14.5     2.00       105.7     0.690    0.463  21400084
#
#          min  off_rating  opponent_id  ...     pace  period    pie  season  \
# 0  240:00:00       105.7   1610612761  ...    97.50       f  0.453    2014
# 1  240:00:00       109.1   1610612754  ...    95.38       f  0.606    2014
# 2  240:00:00        91.2   1610612759  ...    98.28       f  0.439    2014
# 3  265:00:00       102.4   1610612766  ...    98.46       f  0.458    2014
# 4  240:00:00       109.8   1610612752  ...    92.34       f  0.541    2014
#
#       team_id  tm_tov_pct  treb_pct  ts_pct  usg_pct   team
# 0  1610612737        19.7         0   0.583    0.196  Hawks
# 1  1610612737        13.9         0   0.611    0.198  Hawks
# 2  1610612737        13.9         0   0.475    0.198  Hawks
# 3  1610612737        15.8         0   0.564    0.200  Hawks
# 4  1610612737         9.6         0   0.532    0.198  Hawks
#
# [5 rows x 21 columns]

# %%
finalSVUStats.head()
# Out:
#    cfga  cfgm  dfga  dfgm  dist  drbc  ftast   game_id  opponent_id  orbc  \
# 0    39    17    33    13  9.99    56      3  21400008   1610612761    23
# 1    28    12    26    17  9.99    58      4  21400032   1610612754    12
# 2    51    23    35    19  9.99    50      1  21400064   1610612759    32
# 3    45    21    34    23  9.99    53      1  21400071   1610612766    14
# 4    42    19    35    23  9.99    52      3  21400084   1610612752    21
#
#    pass period  sast  season  spd  tchs     team_id  ufga  ufgm   team
# 0   127      f     9    2014    0   127  1610612737    41    23  Hawks
# 1   127      f     5    2014    0   127  1610612737    41    23  Hawks
# 2   127      f     3    2014    0   127  1610612737    41    15  Hawks
# 3   127      f     6    2014    0   127  1610612737    48    22  Hawks
# 4   127      f     4    2014    0   127  1610612737    39    14  Hawks

# %%
miscTeamStats.head()
# Out:
#    blk  blka   game_id  opp_pts_2nd_chance  opp_pts_fb  opp_pts_off_tov  \
# 0    8     9  21400008                  26          18               23
# 1    6     5  21400032                  24           5               13
# 2    5     9  21400064                  14          18               15
# 3    2     7  21400071                  22           1               22
# 4    5     6  21400084                  15           9               12
#
#    opp_pts_paint  opponent_id period  pf  pfd  pts_2nd_chance  pts_fb  \
# 0             40   1610612761      f  24   22              11      10
# 1             26   1610612754      f  20   26               5      15
# 2             34   1610612759      f  25   15              13      11
# 3             50   1610612766      f  30   28              11      15
# 4             40   1610612752      f  17   29              19      10
#
#    pts_off_tov  pts_paint  season     team_id   team
# 0           14         36    2014  1610612737  Hawks
# 1           20         28    2014  1610612737  Hawks
# 2           14         40    2014  1610612737  Hawks
# 3           18         38    2014  1610612737  Hawks
# 4           17         34    2014  1610612737  Hawks

# %%
shotinfo.rename(columns = {"Team":"team"}).head()
# Out:
#         team  season   FGM   FGA   FG%   2pm   2pa       2p%  3PM   3PA ...   \
# 0   Warriors    2014  3410  7137  47.8  2527  4920  0.513618  883  2217 ...
# 1      Hawks    2014  3121  6699  46.6  2303  4547  0.506488  818  2152 ...
# 2    Rockets    2014  3032  6832  44.4  2099  4152  0.505539  933  2680 ...
# 3   Clippers    2014  3228  6830  47.3  2401  4628  0.518799  827  2202 ...
# 4  Grizzlies    2014  3097  6763  45.8  2674  5517  0.484684  423  1246 ...
#
#    DREB   REB   AST   TOV  STL  BLK  BLKA    PF   PFD  +/-
# 0  2814  3667  2248  1185  762  496   293  1628  1541  828
# 1  2611  3326  2111  1167  744  380   404  1457  1611  445
# 2  2624  3582  1820  1366  776  407   437  1803  1730  282
# 3  2711  3495  2031  1012  640  409   245  1749  1766  540
# 4  2634  3490  1777  1094  700  347   424  1567  1662  266
#
# [5 rows x 25 columns]

# %%
advmiscteam = advTeamStats.merge(miscTeamStats,on="game_id")

# %%
advmiscsvuDF = advmiscteam.merge(finalSVUStats,on="game_id")

# %%
teamsDF = advmiscsvuDF[['game_id','team','season','ufga','ufgm','pts_off_tov','pts_paint']]
teamsDF.head()
# Out:
#     game_id     team  season  ufga  ufgm  pts_off_tov  pts_paint
# 0  21400008    Hawks    2014    41    23           14         36
# 1  21400008  Raptors    2014    43    17           14         36
# 2  21400008    Hawks    2014    41    23           23         40
# 3  21400008  Raptors    2014    43    17           23         40
# 4  21400008    Hawks    2014    41    23           14         36

# %%
teamsDF2 = teamsDF.groupby(["team","game_id","season"]).sum()

# %%
teamsDF3 = teamsDF2.reset_index()
teamsDF3.head()
# Out:
#     team   game_id  season  ufga  ufgm  pts_off_tov  pts_paint
# 0  76ers  21400005    2014    88    32           74        160
# 1  76ers  21400023    2014   132    52           86        184
# 2  76ers  21400030    2014   124    60          100        160
# 3  76ers  21400043    2014   144    68          124        132
# 4  76ers  21400058    2014   156    68           68        200

# %%
teamsDF4 = teamsDF3[['team','season','ufga','ufgm','pts_off_tov','pts_paint']]
teamsDF4.head()
# Out:
#     team  season  ufga  ufgm  pts_off_tov  pts_paint
# 0  76ers    2014    88    32           74        160
# 1  76ers    2014   132    52           86        184
# 2  76ers    2014   124    60          100        160
# 3  76ers    2014   144    68          124        132
# 4  76ers    2014   156    68           68        200

# %% [markdown]
# df1 = teamsDF4.loc[teamsDF4["team"]=="Bulls"]
#
# writer = pd.ExcelWriter('NBA.xlsx')
# df1.to_excel(writer,'Sheet1')

# %%
teamsDF5 = teamsDF4.groupby(["team","season"]).sum()
teamsDF6 = teamsDF5.reset_index()
teamsDF6["ufgp"] = teamsDF6["ufgm"] / teamsDF6["ufga"]
teamsDF6.sort_values("ufgp",ascending = False).head()
# Out:
#         team  season   ufga  ufgm  pts_off_tov  pts_paint      ufgp
# 85  Warriors    2015  16728  8280         6948      18348  0.494978
# 89   Wizards    2016   1384   648          608       1512  0.468208
# 84  Warriors    2014  16408  7664         7050      17724  0.467089
# 86  Warriors    2016   1436   668          640       1684  0.465181
# 15  Clippers    2014  16248  7528         5926      15028  0.463319

# %% [markdown]
# df1 = teamsDF5
# writer = pd.ExcelWriter('NBADF.xlsx')
# df1.to_excel(writer,'Sheet1')

# %%
winslosses2 = winslosses.rename(columns={"Team":"team","Season":"season"})
winslosses2.head()
# Out:
#         team  Wins  Losses  season
# 0   Warriors    67      15    2014
# 1      Hawks    60      22    2014
# 2    Rockets    56      26    2014
# 3   Clippers    56      26    2014
# 4  Grizzlies    55      27    2014

# %%
FinalNBADF = teamsDF6.merge(winslosses2,on=["team","season"])

# %%
FinalNBADF.sort_values("Wins",ascending=False).head()
# Out:
#         team  season   ufga  ufgm  pts_off_tov  pts_paint      ufgp  Wins  \
# 82  Warriors    2015  16728  8280         6948      18348  0.494978    73
# 81  Warriors    2014  16408  7664         7050      17724  0.467089    67
# 70     Spurs    2015  14888  6848         7772      21476  0.459968    67
# 83  Warriors    2016   1436   668          640       1684  0.465181    67
# 71     Spurs    2016   1548   656          568       1476  0.423773    61
#
#     Losses
# 82       9
# 81      15
# 70      15
# 83      15
# 71      21

# %%
shotinfo.head()
# Out:
#         Team  season   FGM   FGA   FG%   2pm   2pa       2p%  3PM   3PA ...   \
# 0   Warriors    2014  3410  7137  47.8  2527  4920  0.513618  883  2217 ...
# 1      Hawks    2014  3121  6699  46.6  2303  4547  0.506488  818  2152 ...
# 2    Rockets    2014  3032  6832  44.4  2099  4152  0.505539  933  2680 ...
# 3   Clippers    2014  3228  6830  47.3  2401  4628  0.518799  827  2202 ...
# 4  Grizzlies    2014  3097  6763  45.8  2674  5517  0.484684  423  1246 ...
#
#    DREB   REB   AST   TOV  STL  BLK  BLKA    PF   PFD  +/-
# 0  2814  3667  2248  1185  762  496   293  1628  1541  828
# 1  2611  3326  2111  1167  744  380   404  1457  1611  445
# 2  2624  3582  1820  1366  776  407   437  1803  1730  282
# 3  2711  3495  2031  1012  640  409   245  1749  1766  540
# 4  2634  3490  1777  1094  700  347   424  1567  1662  266
#
# [5 rows x 25 columns]

# %%
shotinfo2 = shotinfo[["Team", "season"]]

# %%
shotinfo2 = shotinfo.rename(columns = {"Team":"team"})

# %%
FinalDF = FinalNBADF.merge(shotinfo2,on=["team","season"])
FinalDF.sort_values("pts_paint",ascending=True)
FinalDF["UncontestedAssists"] = FinalDF["ufgm"] / FinalDF["AST"]
FinalDF.head()
# Out:
#     team  season   ufga  ufgm  pts_off_tov  pts_paint      ufgp  Wins  Losses  \
# 0  76ers    2014  11856  4616         6202      13532  0.389339    18      64
# 1  76ers    2015  12640  5200         7514      18092  0.411392    10      72
# 2  76ers    2016   1564   628          626       1520  0.401535    28      54
# 3  Bucks    2014  13048  5828         6326      14388  0.446658    41      41
# 4  Bucks    2015   9676  4340         5922      15476  0.448532    33      49
#
#     FGM         ...           REB   AST   TOV  STL  BLK  BLKA    PF   PFD  \
# 0  2765         ...          3514  1683  1453  789  487   454  1778  1657
# 1  2970         ...          3382  1765  1343  680  495   466  1780  1571
# 2  3088         ...          3513  1949  1366  692  420   446  1793  1610
# 3  3083         ...          3450  1932  1373  789  403   392  1814  1649
# 4  3145         ...          3417  1895  1247  672  475   462  1695  1600
#
#    +/-  UncontestedAssists
# 0 -736            2.742721
# 1 -839            2.946176
# 2 -467            0.322217
# 3   35            3.016563
# 4 -343            2.290237
#
# [5 rows x 33 columns]

# %%
FinalDF2 = FinalDF.merge(NBAstatsTeam, on=["team","season"])
FinalDF2.head()
# Out:
#     team  season   ufga  ufgm  pts_off_tov  pts_paint      ufgp  Wins  Losses  \
# 0  76ers    2014  11856  4616         6202      13532  0.389339    18      64
# 1  76ers    2015  12640  5200         7514      18092  0.411392    10      72
# 2  76ers    2016   1564   628          626       1520  0.401535    28      54
# 3  Bucks    2014  13048  5828         6326      14388  0.446658    41      41
# 4  Bucks    2015   9676  4340         5922      15476  0.448532    33      49
#
#     FGM  ...   AST/TO  AST RAT  OREB%  DREB%  REB%  TOV%  EFG%   TS%    PACE  \
# 0  2765  ...     1.48     18.5   26.4   78.3  53.1  17.1  51.8  55.3  103.13
# 1  2970  ...     1.31     16.3   20.6   74.0  46.4  16.2  48.7  51.9  100.23
# 2  3088  ...     1.43     17.6   22.4   75.3  48.8  16.4  50.1  53.9  100.96
# 3  3083  ...     1.67     17.5   18.8   76.3  47.3  13.7  53.4  56.9   97.37
# 4  3145  ...     1.52     17.7   24.9   73.1  49.2  15.7  49.9  53.7   96.55
#
#     PIE
# 0  51.3
# 1  42.8
# 2  47.0
# 3  50.3
# 4  48.3
#
# [5 rows x 51 columns]

# %%
FinalDF3 = FinalDF2.merge(teamDef, on = ["team","season"])
FinalDF3.head()
finalDFcorr = FinalDF3

# %%
FinalDF3["Wins"].corr(FinalDF3["ufgp"])
# Out:
# 0.46855361898066494

# %%
finalDFcolumns = FinalDF3.columns.values.tolist()
finalDFcolumns
# Out:
# ['team',
#  'season',
#  'ufga',
#  'ufgm',
#  'pts_off_tov',
#  'pts_paint',
#  'ufgp',
#  'Wins',
#  'Losses',
#  'FGM',
#  'FGA',
#  'FG%',
#  '2pm',
#  '2pa',
#  '2p%',
#  '3PM',
#  '3PA',
#  '3P%',
#  'FTM',
#  'FTA',
#  'FT%',
#  'OREB',
#  'DREB_x',
#  'REB',
#  'AST',
#  'TOV',
#  'STL_x',
#  'BLK_x',
#  'BLKA',
#  'PF',
#  'PFD',
#  '+/-',
#  'UncontestedAssists',
#  'GP_x',
#  'W_x',
#  'L_x',
#  'MIN_x',
#  'OFFRTG',
#  'DEFRTG',
#  'NETRTG',
#  'AST%',
#  'AST/TO',
#  'AST RAT',
#  'OREB%',
#  'DREB%_x',
#  'REB%',
#  'TOV%',
#  'EFG%',
#  'TS%',
#  'PACE',
#  'PIE',
#  'GP_y',
#  'W_y',
#  'L_y',
#  'MIN_y',
#  'DEF\xa0RTG',
#  'DREB_y',
#  'DREB%_y',
#  'STL_y',
#  'BLK_y',
#  'OPP\xa0PTS OFF\xa0TOV',
#  'OPP\xa0PTS 2ND\xa0CHANCE',
#  'OPP\xa0PTS FB',
#  'OPP\xa0PTS PAINT']

# %%
FinalDFcorr = FinalDF3[['ufga',
 'ufgm',
 'pts_off_tov',
 'pts_paint',
 'ufgp',
 'Wins',
 'Losses',
 'OREB',
 'DREB_x',
 'REB',
 'AST',
 'TOV',
 'STL_x',
 'BLK_x',
 'BLKA',
 'PF',
 'PFD',
 '+/-',
 'UncontestedAssists',
 'OFFRTG',
 'DEFRTG',
 'NETRTG',
 'AST%',
 'AST/TO',
 'AST RAT',
 'OREB%',
 'DREB%_x',
 'REB%',
 'TOV%',
 'EFG%',
 'TS%',
 'PACE',
 'PIE',
 'DEF\xa0RTG',
 'DREB_y',
 'DREB%_y',
 'STL_y',
 'BLK_y',
 'OPP\xa0PTS OFF\xa0TOV',
 'OPP\xa0PTS 2ND\xa0CHANCE',
 'OPP\xa0PTS FB',
 'OPP\xa0PTS PAINT']]

# %%
FinalDF3["Wins"].corr(FinalDF3["TOV%"])
# Out:
# -0.22778305122142925

# %%
FinalDF3.to_csv('FinalDF3.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = FinalDFcorr.corr()

fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

plt.show()

# %%
FinalDF3.to_excel("FinalDF.xls")

# %%
# Andy - linear regression 
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
sns.jointplot(x="Wins", y="OFFRTG", data=FinalDF3, kind="reg", size=8);
plt.savefig('OFFRTG.png')

# %%
# filter 2014
season_2014 = FinalDF3[FinalDF3['season']== 2014]
season_2014.head()
# Out:
#          team  season   ufga  ufgm  pts_off_tov  pts_paint      ufgp  Wins  \
# 0       76ers    2014  11856  4616         6202      13532  0.389339    18
# 3       Bucks    2014  13048  5828         6326      14388  0.446658    41
# 6       Bulls    2014  14188  6068         5732      15736  0.427685    50
# 9   Cavaliers    2014  15680  6772         6624      17432  0.431888    53
# 12    Celtics    2014  14060  5956         5742      14784  0.423613    40
#
#     Losses   FGM      ...        MIN_y  DEF RTG  DREB_y  DREB%_y  STL_y  \
# 0       64  2765      ...         3961      102    2536     73.0    789
# 3       41  3083      ...         3986       99    2574     73.3    789
# 6       32  3001      ...         3976      102    2792     74.4    514
# 9       29  3089      ...         3956      104    2612     74.7    603
# 12      42  3193      ...         3976      102    2685     75.0    674
#
#     BLK_y  OPP PTS OFF TOV  OPP PTS 2ND CHANCE  OPP PTS FB  OPP PTS PAINT
# 0     487             1687                1144        1200           3420
# 3     403             1374                1092         877           3262
# 6     476             1258                1079        1065           3344
# 9     340             1329                1017         970           3502
# 12    294             1325                1108         890           3658
#
# [5 rows x 64 columns]

# %%
# filter 2015
season_2015 = FinalDF3[FinalDF3['season']== 2015]
season_2015.head()
# Out:
#          team  season   ufga  ufgm  pts_off_tov  pts_paint      ufgp  Wins  \
# 1       76ers    2015  12640  5200         7514      18092  0.411392    10
# 4       Bucks    2015   9676  4340         5922      15476  0.448532    33
# 7       Bulls    2015  13356  5840         6488      17716  0.437257    42
# 10  Cavaliers    2015  15932  7128         6218      15892  0.447401    57
# 13    Celtics    2015  13976  5812         7596      19812  0.415856    48
#
#     Losses   FGM      ...        MIN_y  DEF RTG  DREB_y  DREB%_y  STL_y  \
# 1       72  2970      ...         3961      107    2605     74.0    680
# 4       49  3145      ...         3966      106    2559     73.1    672
# 7       40  3165      ...         3981      104    2889     74.9    495
# 10      25  3171      ...         3971      102    2777     78.5    551
# 13      34  3216      ...         3956      101    2733     74.6    752
#
#     BLK_y  OPP PTS OFF TOV  OPP PTS 2ND CHANCE  OPP PTS FB  OPP PTS PAINT
# 1     495             1639                1207        1370           3736
# 4     475             1453                1153        1068           3606
# 7     470             1314                1169        1128           3642
# 10    317             1278                 919         917           3344
# 13    348             1211                1164         888           3524
#
# [5 rows x 64 columns]

# %%
# filter 2016
season_2016 = FinalDF3[FinalDF3['season']== 2016]
season_2016.head()
# Out:
#          team  season  ufga  ufgm  pts_off_tov  pts_paint      ufgp  Wins  \
# 2       76ers    2016  1564   628          626       1520  0.401535    28
# 5       Bucks    2016  1288   524          660       1644  0.406832    42
# 8       Bulls    2016  1476   640          670       1800  0.433604    41
# 11  Cavaliers    2016  1400   612          500       1260  0.437143    51
# 14    Celtics    2016  1396   608          562       1560  0.435530    53
#
#     Losses   FGM      ...        MIN_y  DEF RTG  DREB_y  DREB%_y  STL_y  \
# 2       54  3088      ...         3966      106    2706     75.3    692
# 5       40  3182      ...         3956      106    2589     75.4    666
# 8       41  3169      ...         3956      105    2797     76.8    643
# 11      31  3275      ...         3976      108    2821     75.8    539
# 14      29  3168      ...         3951      106    2698     75.3    617
#
#     BLK_y  OPP PTS OFF TOV  OPP PTS 2ND CHANCE  OPP PTS FB  OPP PTS PAINT
# 2     420             1517                1106        1256           3698
# 5     436             1331                1040         961           3580
# 8     393             1267                 977        1125           3710
# 11    327             1365                1122        1094           3650
# 14    340             1245                1143        1002           3544
#
# [5 rows x 64 columns]

# %%
# Andy import FinalDF3 where duplicate columns were dropped
FinalDF4 = pd.read_csv("FinalDF3_dropdups.csv")
FinalDF4.head()
# Out:
#     team  season   ufga  ufgm  pts_off_tov  pts_paint      ufgp  Wins  Losses  \
# 0  76ers    2014  11856  4616         6202      13532  0.389339    18      64
# 1  76ers    2015  12640  5200         7514      18092  0.411392    10      72
# 2  76ers    2016   1564   628          626       1520  0.401535    28      54
# 3  Bucks    2014  13048  5828         6326      14388  0.446658    41      41
# 4  Bucks    2015   9676  4340         5922      15476  0.448532    33      49
#
#     FGM      ...        DREB%  TOV%  EFG%   TS%    PACE   PIE  \
# 0  2765      ...         78.3  17.1  51.8  55.3  103.13  51.3
# 1  2970      ...         74.0  16.2  48.7  51.9  100.23  42.8
# 2  3088      ...         75.3  16.4  50.1  53.9  100.96  47.0
# 3  3083      ...         76.3  13.7  53.4  56.9   97.37  50.3
# 4  3145      ...         73.1  15.7  49.9  53.7   96.55  48.3
#
#    OPP PTS OFF TOV  OPP PTS 2ND CHANCE  OPP PTS FB  OPP PTS PAINT
# 0             1687                1144        1200           3420
# 1             1639                1207        1370           3736
# 2             1517                1106        1256           3698
# 3             1374                1092         877           3262
# 4             1453                1153        1068           3606
#
# [5 rows x 51 columns]

# %% [markdown]
# <br><br>
# **Analyze Correlation for all seasons bewtween Wins and Defensive Stats**

# %%
# Andy - analyze defensive stats
FinalDF4_defense = FinalDF4.filter(['team', 'pts_off_tov', 'Wins', 'Losses', 'DREB', 'STL', 'BLK', 'DEFRTG'])

# %%
# Andy - print defense DF
FinalDF4_defense.head()
# Out:
#     team  pts_off_tov  Wins  Losses  DREB  STL  BLK  DEFRTG
# 0  76ers         6202    18      64  2536  789  487   104.2
# 1  76ers         7514    10      72  2605  680  495   106.7
# 2  76ers          626    28      54  2706  692  420   106.4
# 3  Bucks         6326    41      41  2574  789  403   106.5
# 4  Bucks         5922    33      49  2559  672  475   105.7

# %%
# Andy - get shape of defense DF
FinalDF4_defense.shape
# Out:
# (87, 8)

# %%
# Sort Win Columns 
FinalDF4_defense.sort_values('Wins', ascending=False).head()
# Out:
#         team  pts_off_tov  Wins  Losses  DREB  STL  BLK  DEFRTG
# 82  Warriors         6948    73       9  2972  689  498   100.9
# 81  Warriors         7050    67      15  2814  762  496   101.3
# 70     Spurs         7772    67      15  2831  677  485    96.6
# 83  Warriors          640    67      15  2873  785  555   101.1
# 71     Spurs          568    61      21  2777  655  484   100.9

# %%
# Andy - Correlation test pts_off_tov and Wins
FinalDF4_defense['Wins'].corr(FinalDF4_defense['pts_off_tov'])
# Out:
# 0.085271115026012478

# %%
# Andy - Correlation test
FinalDF4_defense[['Wins', 'pts_off_tov']].corr()
# Out:
#                  Wins  pts_off_tov
# Wins         1.000000     0.085271
# pts_off_tov  0.085271     1.000000

# %% [markdown]
# **Positive Correlation between Wins and Defensive Rebounds**

# %%
# Andy - Correlation DREB
FinalDF4_defense[['Wins', 'DREB']].corr()
# Out:
#           Wins      DREB
# Wins  1.000000  0.421766
# DREB  0.421766  1.000000

# %%
# Andy - Correlation Wins vs Steals
FinalDF4_defense[['Wins', 'STL']].corr()
# Out:
#           Wins       STL
# Wins  1.000000  0.181786
# STL   0.181786  1.000000

# %%
# Andy - Correlation Wins vs Blocks
FinalDF4_defense[['Wins', 'BLK']].corr()
# Out:
#          Wins      BLK
# Wins  1.00000  0.28739
# BLK   0.28739  1.00000

# %%
# Andy - Points allowed per 100 posessions
FinalDF4_defense[['Wins', 'DEFRTG']].corr()
# Out:
#             Wins    DEFRTG
# Wins    1.000000 -0.538066
# DEFRTG -0.538066  1.000000

# %%
# Andy - heat map

# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

corr = FinalDF4_defense.corr()

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
            cmap="YlGnBu");

# %%
# Andy - linear regression wins vs dreb
sns.set(color_codes=True)
sns.lmplot(x="Wins", y="DREB", data=FinalDF4_defense, size=8);

# %%
# Andy - linear regression 2
sns.set(color_codes=True)
sns.jointplot(x="Wins", y="DREB", data=FinalDF4_defense, kind="reg", size=8);
plt.savefig('test.png')

# %%
# Andy - Sort DF by DREB
FinalDF4_defense.sort_values('DREB', ascending=False).head()
# Out:
#         team  pts_off_tov  Wins  Losses  DREB  STL  BLK  DEFRTG
# 82  Warriors         6948    73       9  2972  689  498   100.9
# 76   Thunder         8906    55      27  2916  603  487   103.0
# 7      Bulls         6488    42      40  2889  495  470   103.9
# 59  Pelicans          624    34      48  2879  638  453   104.9
# 50      Nets          640    20      62  2879  593  387   108.0
